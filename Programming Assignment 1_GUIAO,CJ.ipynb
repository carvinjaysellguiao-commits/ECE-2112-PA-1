# %% [markdown]
# # ECE 2112: Advanced Computer Programming and Algorithms

# %% [markdown]
# ## Experiment 1: Introduction to Python Programming

# %% [markdown]
# Made by: Guiao, Carvin Jaysell D. | 2ECE-D
#
# The content contains Programming Assignment 1. This project covers three Python problems in Basic Computing with Python.

# %% [markdown]
# ### A. Word Rotation Problem

# %%
def rotate_word(text):
    if len(text) == 1:
        return text 

    return text[1:] + text[0]

# %% [markdown]
# **Sample Run:**

# %%
print(rotate_word("python"))
# Out:
# ythonp

# %%
print(rotate_word("logic"))
# Out:
# ogicl

# %%
print(rotate_word("Code"))
# Out:
# odeC

# %%
print(rotate_word("A"))
# Out:
# A

# %% [markdown]
# ### B. Username Builder Problem

# %%
def make_username(first_name, last_name):
    first = first_name.lower().replace(" ", "")
    last = last_name.lower().replace(" ", "")
    return first + "." + last

# %% [markdown]
# **Sample Run:**

# %%
make_username("Ada", "Lovelace")
# Out:
# 'ada.lovelace'

# %%
make_username("Alan", "Turing")
# Out:
# 'alan.turing'

# %%
make_username("Ana Maria", "De Leon")
# Out:
# 'anamaria.deleon'

# %% [markdown]
# ### C. Bookend Swap Problem

# %%
def swap_bookends(items):
    first, *middle, last = items
    return [last, *middle, first]

# %% [markdown]
# **Sample Run:**

# %%
print(swap_bookends([1, 2, 3, 4, 5, 6]))
# Out:
# [6, 2, 3, 4, 5, 1]

# %%
print(swap_bookends(["red", "green", "blue"]))
# Out:
# ['blue', 'green', 'red']

# %%
print(swap_bookends([8, 3]))
# Out:
# [3, 8]
